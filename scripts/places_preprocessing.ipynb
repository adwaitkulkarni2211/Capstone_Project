# %% [markdown]
# ### Merging all csv files

# %%
import pandas as pd
import os

# Set the directory where the CSV files are located
directory = "./Datasets"

# Create an empty list to store the dataframes
dfs = []

# Loop through each file in the directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        # Read the CSV file into a pandas dataframe and append it to the list
        filepath = os.path.join(directory, filename)
        df = pd.read_csv(filepath)
        dfs.append(df)

# Merge all the dataframes in the list into a single dataframe
merged_df = pd.concat(dfs, ignore_index=True)
merged_df
# Out:
#          type        id geometry/type  geometry/coordinates/0  \
# 0     Feature   9725727         Point               72.571793
# 1     Feature   9725726         Point               72.572502
# 2     Feature  11447953         Point               72.567360
# 3     Feature  11447952         Point               72.568848
# 4     Feature  11263778         Point               72.577339
# ...       ...       ...           ...                     ...
# 2460  Feature   8594529         Point               72.830902
# 2461  Feature   7082282         Point               72.831009
# 2462  Feature   7982585         Point               72.816658
# 2463  Feature   5686420         Point               72.950737
# 2464  Feature  14469963         Point               72.850998
#
#       geometry/coordinates/1 properties/xid           properties/name  \
# 0                  23.023519     N440015518                   Sakar 4
# 1                  23.022966     N440015517                   Sakar 2
# 2                  23.024933    N5274771822             Villa Shodhan
# 3                  23.026508    N1964926905                Gandhigram
# 4                  23.022081     W605629475                Manek Burj
# ...                      ...            ...                       ...
# 2460               19.141336     W193632118             Infinity Mall
# 2461               19.141422    N2125320198           Cinemax Versova
# 2462               19.129932    N3186375634          Someshwar Temple
# 2463               19.037353     W315277378     sunni islakiya masjid
# 2464               19.000999       Q7458297  Sewri Christian Cemetery
#
#       properties/dist  properties/rate   properties/osm  \
# 0          119.685029                1   node/440015518
# 1          124.220107                1   node/440015517
# 2          493.854279                3  node/5274771822
# 3          515.384995                2  node/1964926905
# 4          610.685878                3    way/605629475
# ...               ...              ...              ...
# 2460      8749.467287                1    way/193632118
# 2461      8751.322002                1  node/2125320198
# 2462      8769.410054                1  node/3186375634
# 2463      8797.520101                1    way/315277378
# 2464      8764.813381                3              NaN
#
#                                        properties/kinds properties/wikidata
# 0     other,unclassified_objects,interesting_places,...                 NaN
# 1     other,unclassified_objects,interesting_places,...                 NaN
# 2     other,unclassified_objects,interesting_places,...            Q2275530
# 3     railway_stations,industrial_facilities,interes...           Q31294840
# 4     historic,monuments_and_memorials,interesting_p...           Q18745720
# ...                                                 ...                 ...
# 2460  cultural,cinemas,theatres_and_entertainments,i...                 NaN
# 2461  cultural,cinemas,theatres_and_entertainments,i...                 NaN
# 2462          religion,hindu_temples,interesting_places                 NaN
# 2463          religion,other_temples,interesting_places                 NaN
# 2464  cemeteries,historic,burial_places,interesting_...            Q7458297
#
# [2465 rows x 12 columns]

# %% [markdown]
# ### Selecting desired columns and renaming them

# %%
new_df = merged_df[['id', 'geometry/coordinates/0', 'geometry/coordinates/1', 'properties/name', 'properties/kinds']].copy()
new_df.columns = ['features__id', 'features__geometry__coordinates__001', 'features__geometry__coordinates__002', 'features__properties__name', 'features__properties__kinds']
new_df
# Out:
#       features__id  features__geometry__coordinates__001  \
# 0          9725727                             72.571793
# 1          9725726                             72.572502
# 2         11447953                             72.567360
# 3         11447952                             72.568848
# 4         11263778                             72.577339
# ...            ...                                   ...
# 2460       8594529                             72.830902
# 2461       7082282                             72.831009
# 2462       7982585                             72.816658
# 2463       5686420                             72.950737
# 2464      14469963                             72.850998
#
#       features__geometry__coordinates__002 features__properties__name  \
# 0                                23.023519                    Sakar 4
# 1                                23.022966                    Sakar 2
# 2                                23.024933              Villa Shodhan
# 3                                23.026508                 Gandhigram
# 4                                23.022081                 Manek Burj
# ...                                    ...                        ...
# 2460                             19.141336              Infinity Mall
# 2461                             19.141422            Cinemax Versova
# 2462                             19.129932           Someshwar Temple
# 2463                             19.037353      sunni islakiya masjid
# 2464                             19.000999   Sewri Christian Cemetery
#
#                             features__properties__kinds
# 0     other,unclassified_objects,interesting_places,...
# 1     other,unclassified_objects,interesting_places,...
# 2     other,unclassified_objects,interesting_places,...
# 3     railway_stations,industrial_facilities,interes...
# 4     historic,monuments_and_memorials,interesting_p...
# ...                                                 ...
# 2460  cultural,cinemas,theatres_and_entertainments,i...
# 2461  cultural,cinemas,theatres_and_entertainments,i...
# 2462          religion,hindu_temples,interesting_places
# 2463          religion,other_temples,interesting_places
# 2464  cemeteries,historic,burial_places,interesting_...
#
# [2465 rows x 5 columns]

# %%
new_df.isnull().sum()
# Out:
# features__id                              0
# features__geometry__coordinates__001      0
# features__geometry__coordinates__002      0
# features__properties__name              435
# features__properties__kinds               0
# dtype: int64

# %%
new_df.columns.tolist()
# Out:
# ['features__id',
#  'features__geometry__coordinates__001',
#  'features__geometry__coordinates__002',
#  'features__properties__name',
#  'features__properties__kinds']

# %%
new_df = new_df.dropna()
new_df = new_df[~new_df['features__properties__name'].str.contains('\d', na=False)]

# %%
new_df.to_csv("./Datasets/new_places.csv", index=False)
